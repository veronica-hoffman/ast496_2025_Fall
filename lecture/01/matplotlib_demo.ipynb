# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook 
# last line only needed to make Jupyter play nice with plots

# %%
x = np.arange(0, 51, 1)
y = 10*np.exp(-0.1*x) + np.sin(0.5*x)

# %%
print(y)
# Out:
# [10.          9.52779972  9.02877852  8.40567719  7.61249789  6.66377874
#   5.62923637  4.61506981  3.73648715  3.08816648  2.71987014  2.62317051
#   2.73252662  2.94043792  3.12295624  3.16930158  3.00832343  2.62532235
#   2.06510737  1.42053507  0.80933172  0.34486852  0.10804138  0.12713626
#   0.37060661  0.75452809  1.16290282  1.47583955  1.59870798  1.48512726
#   1.14815852  0.65695951  0.11971872 -0.34295367 -0.62766479 -0.67365217
#  -0.47775002 -0.09524535  0.37358493  0.80795898  1.09610164  1.16255655
#   0.98661141  0.60732459  0.11392209 -0.37608455 -0.74570205 -0.90712926
#  -0.82328089 -0.5168917  -0.06497228]

# %%
plt.plot(x, y, 'k-')
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
plt.plot(x, y, 'ro', label=r'$y = 10e^{-0.1x} + \sin(\frac{x}{2})$')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot([10, 20, 30, 40, 50, 60]) # show plot and return immediately
plt.show(block=False)
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %% [markdown]
# # You can modify plots you've already created

# %%
plt.ylabel('new label')      # oops! forgot to add y-label
plt.draw()                   # updates current plot window
line3 = plt.plot([2, 4, 5, 3, 1, 0]) # add a new plot
plt.draw()                   # update plot window

# %% [markdown]
# # You can even modify elements on plots you've created like our orange line - see whats going to happen to it...

# %%
plt.get(line3)
# Out:
#     agg_filter = None
#     alpha = None
#     animated = False
#     antialiased or aa = True
#     bbox = Bbox(x0=0.0, y0=0.0, x1=5.0, y1=5.0)
#     children = []
#     clip_box = TransformedBbox(     Bbox(x0=0.0, y0=0.0, x1=1.0, ...
#     clip_on = True
#     clip_path = None
#     color or c = #ff7f0e
#     dash_capstyle = butt
#     dash_joinstyle = round
#     data = (array([0., 1., 2., 3., 4., 5.]), array([2, 4, 5, ...
#     drawstyle or ds = default
#     figure = Figure(640x480)
#     fillstyle = full
#     gapcolor = None
#     gid = None
#     in_layout = True
#     label = _child1
#     linestyle or ls = -
#     linewidth or lw = 1.5
#     marker = None
#     markeredgecolor or mec = #ff7f0e
#     markeredgewidth or mew = 1.0
#     markerfacecolor or mfc = #ff7f0e
#     markerfacecoloralt or mfcalt = none
#     markersize or ms = 6.0
#     markevery = None
#     mouseover = False
#     path = Path(array([[0., 2.],        [1., 4.],        [2.,...
#     path_effects = []
#     picker = None
#     pickradius = 5
#     rasterized = False
#     sketch_params = None
#     snap = None
#     solid_capstyle = projecting
#     solid_joinstyle = round
#     tightbbox = Bbox(x0=80.0, y0=52.8, x1=576.0, y1=422.4)
#     transform = CompositeGenericTransform(     TransformWrapper(  ...
#     transformed_clip_path_and_affine = (None, None)
#     url = None
#     visible = True
#     window_extent = Bbox(x0=80.0, y0=52.8, x1=2560.0, y1=1900.79999999...
#     xdata = [0. 1. 2. 3. 4. 5.]
#     xydata = [[0. 2.]  [1. 4.]  [2. 5.]  [3. 3.]  [4. 1.]  [5. ...
#     ydata = [2 4 5 3 1 0]
#     zorder = 2

# %%
plt.setp(line3, linestyle='dashed', lw=4, color='crimson')
# Out:
# [None, None, None]

# %%
plt.figure(figsize=(5,3))
x = np.random.randn(1000)
y = np.random.randn(1000)
colors = np.random.rand(1000)
sizes = 50*np.random.randn(1000)
plt.scatter(x, y, s=sizes, c=colors, cmap='turbo', edgecolor='black')
plt.grid()
ax = plt.gca()
ax.set_xlabel('x')
ax.set_ylabel('y')
fig = plt.gcf()
title = fig.suptitle('blah', fontsize=20)
title.set_fontname('Arial')
title.set_fontstyle('oblique')
title.set_color('C1')
# Out:
# <img src="data:image/png;base64,..." width="500.50000000000006">
# /Users/gnarayan/miniconda3/envs/ideas/lib/python3.11/site-packages/matplotlib/collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
plt.figure()
ax2 = plt.gcf().add_subplot()
x = np.linspace(0, 2*np.pi, 20)
y = np.sin(x)
y_errors = np.abs(0.1*np.cos(x))
ax2.errorbar(x, y, yerr=y_errors, fmt='.-')
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# # Each of the next cells until the next plt.figure() will modify the above axis - try to guess what happens before you run the cell

# %%
plt.axis([2, 5, -0.5, 0.5])
# Out:
# (2.0, 5.0, -0.5, 0.5)

# %%
plt.axis('tight')
# Out:
# (-0.3141592653589793,
#  6.5973445725385655,
#  -1.1053266703092934,
#  1.1053266703092934)

# %%
plt.axis('equal')
# Out:
# (-0.3141592653589793,
#  6.5973445725385655,
#  -1.1053266703092934,
#  1.1053266703092934)

# %%
plt.axis('off')
# Out:
# (-0.3141592653589793,
#  6.5973445725385655,
#  -1.1053266703092934,
#  1.1053266703092934)

# %%
plt.figure(figsize=(5, 3))
x = np.linspace(0, 4*np.pi, 1000)
plt.plot(x, np.sin(x), label='sin(x)')
plt.plot(x, np.cos(x), label='cos(x)')
plt.plot(x, np.tan(x), label='_nolegend_')
plt.legend(loc='upper left')
plt.ylim(-5, 5)
plt.text(np.pi, -2, r'Random Greek: $\alpha = \int_0^1 f(x) dx$', fontsize=16, rotation=45)
# Out:
# <img src="data:image/png;base64,..." width="500.50000000000006">
# Text(3.141592653589793, -2, 'Random Greek: $\\alpha = \\int_0^1 f(x) dx$')

# %%
plt.figure(figsize=(3, 3))
x = 100. + 15.*np.random.randn(10000)
n, bins, patches = plt.hist(x, 50, density=True, facecolor='g')
# Out:
# <img src="data:image/png;base64,..." width="299.75">
